# %% [markdown]
# <a href="https://colab.research.google.com/github/Affanaf21/-231A023-_NLP-Experiments/blob/main/NLPexp7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install svgling

import nltk
from nltk import pos_tag, word_tokenize
from nltk.chunk import RegexpParser
from IPython.display import display
import svgling

# Create a chunk parser with the combined grammar defined in grammar1
chunk_parser = RegexpParser(grammar1)

# Parse the tagged sentence to get chunked phrases
chunked1 = chunk_parser.parse(tagged)

# Print the chunked output
print(chunked1)

# Display the chunked output as a tree using svgling
display(chunked1)
# Out:
# ...
# (S
#   (VP waiting/VBG)
#   for/IN
#   (NP a/DT cup/NN)
#   of/IN
#   (NP tea/NN)
#   in/IN
#   (NP dubai/NN)
#   with/IN
#   (NP salman/NN)
#   ./.)
# Tree('S', [Tree('VP', [('waiting', 'VBG')]), ('for', 'IN'), Tree('NP', [('a', 'DT'), ('cup', 'NN')]), ('of', 'IN'), Tree('NP', [('tea', 'NN')]), ('in', 'IN'), Tree('NP', [('dubai', 'NN')]), ('with', 'IN'), Tree('NP', [('salman', 'NN')]), ('.', '.')])

# %%
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Sample sentence
sentence ="glory days will be back soon."
sentence1 = "waiting for a cup of tea in dubai with salman."

# %%
import nltk
from nltk import word_tokenize, pos_tag

# %%
nltk.download('averaged_perceptron_tagger_eng')
tokens = word_tokenize(sentence1)
tagged = pos_tag(tokens)
tagged
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('waiting', 'VBG'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('cup', 'NN'),
#  ('of', 'IN'),
#  ('tea', 'NN'),
#  ('in', 'IN'),
#  ('dubai', 'NN'),
#  ('with', 'IN'),
#  ('salman', 'NN'),
#  ('.', '.')]

# %%
nltk.download('tagsets_json')
nltk.help.upenn_tagset("VBD")
# Out:
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!

# %%
#e.g., NP -> Noun Phrase)
grammar = 'NP: {<DT>?<JJ>*<NN>}'

# %%
#Step 3: Create a chunk parser and parse the sentence
chunk_parser = RegexpParser (grammar)
chunked = chunk_parser.parse(tagged)
# Display the chunked output
print(chunked)
# Out:
# (S
#   waiting/VBG
#   for/IN
#   (NP a/DT cup/NN)
#   of/IN
#   (NP tea/NN)
#   in/IN
#   (NP dubai/NN)
#   with/IN
#   (NP salman/NN)
#   ./.)

# %%
import nltk
# Download the necessary resources
nltk.download("punkt")
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.chunk import ne_chunk
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
grammar1 = """
NP: {<DT>?<JJ>*<NN>+}
VP: {<MD>?<VB.*><RB.*>*<VB.*>*}
"""
chunk_parser = RegexpParser (grammar1)
chunked1 = chunk_parser.parse(tagged)

# %%
#Display the chunked output
print(chunked1)

# Import necessary modules for displaying tree (ensure svgling is installed first)
from IPython.display import display
import svgling

# Display the chunked output as a tree using svgling
display(chunked1)
# Out:
# (S
#   (VP waiting/VBG)
#   for/IN
#   a/DT
#   cup/NN
#   of/IN
#   tea/NN
#   in/IN
#   dubai/NN
#   with/IN
#   salman/NN
#   ./.)
# Tree('S', [Tree('VP', [('waiting', 'VBG')]), ('for', 'IN'), ('a', 'DT'), ('cup', 'NN'), ('of', 'IN'), ('tea', 'NN'), ('in', 'IN'), ('dubai', 'NN'), ('with', 'IN'), ('salman', 'NN'), ('.', '.')])

# %%
named_entities = ne_chunk(tagged)
print(named_entities)
# Out:
# (S
#   waiting/VBG
#   for/IN
#   a/DT
#   cup/NN
#   of/IN
#   tea/NN
#   in/IN
#   dubai/NN
#   with/IN
#   salman/NN
#   ./.)

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# ...

# %%
print("Named entities:")
print(named_entities)

print("\nType:")
print(type(named_entities))
# Out:
# Named entities:
# (S
#   waiting/VBG
#   for/IN
#   a/DT
#   cup/NN
#   of/IN
#   tea/NN
#   in/IN
#   dubai/NN
#   with/IN
#   salman/NN
#   ./.)
#
# Type:
# <class 'nltk.tree.tree.Tree'>

# %%
# Display named entities
for subtree in named_entities:
    if isinstance(subtree, nltk.Tree):
        entity = " ".join([word for word, tag in subtree.leaves()])
        label = subtree.label()
        print(f"Entity: {entity}, Label: {label}")

# %%
nltk.download('svgling')
import svgling
[nltk_data] = Error loading svgling: Package 'svgling' not found in
[nltk_data]
index
# Out:
#   File "/tmp/ipykernel_879/2615300526.py", line 3
#     [nltk_data] = Error loading svgling: Package 'svgling' not found in
#                         ^
# SyntaxError: invalid syntax
